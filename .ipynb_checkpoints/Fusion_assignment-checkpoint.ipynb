# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/train.csv')
test_df = pd.read_csv('dataset/test.csv')

# %%
df.shape, test_df.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
df.shape, test_df.shape
# Out:
# ((1460, 80), (1459, 80))

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
df.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df['SalePrice'])
plt.title('Distribution of SalePrice')

plt.subplot(1,2,2)
sns.distplot(np.log1p(df['SalePrice']))
plt.title('Log of Distribution of SalePrice')

plt.tight_layout()

# %%
## feature engineering 
## RF and Gradient Boosting
## Root mean square error of log(y) and log(y^)

## handling missing values

# %%
## separating numerical and text data
numeric_feat = df.describe().columns
non_numeric_feat = list(set(df.columns.tolist()) - set(numeric_feat.tolist()))

# %%
numeric_feat, len(numeric_feat)
# Out:
# (Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#         'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#         'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#         'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#         'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#         'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#         'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#         'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#        dtype='object'), 38)

# %%
non_numeric_feat, len(non_numeric_feat)
# Out:
# (['BsmtFinType2',
#   'BsmtFinType1',
#   'MasVnrType',
#   'PoolQC',
#   'BsmtExposure',
#   'BsmtCond',
#   'HeatingQC',
#   'Alley',
#   'SaleCondition',
#   'GarageQual',
#   'Neighborhood',
#   'GarageType',
#   'LandContour',
#   'Electrical',
#   'KitchenQual',
#   'CentralAir',
#   'LotConfig',
#   'SaleType',
#   'BsmtQual',
#   'ExterCond',
#   'FireplaceQu',
#   'Functional',
#   'GarageFinish',
#   'PavedDrive',
#   'HouseStyle',
#   'Condition2',
#   'Utilities',
#   'RoofMatl',
#   'MiscFeature',
#   'RoofStyle',
#   'GarageCond',
#   'LandSlope',
#   'Exterior1st',
#   'Fence',
#   'Exterior2nd',
#   'MSZoning',
#   'ExterQual',
#   'LotShape',
#   'Foundation',
#   'Heating',
#   'Condition1',
#   'BldgType',
#   'Street'],
#  43)

# %%
## maximum possible values of categories in non_numeric_feat

df[non_numeric_feat].describe().ix['unique']
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# BsmtFinType2      6
# BsmtFinType1      6
# MasVnrType        4
# PoolQC            3
# BsmtExposure      4
# BsmtCond          4
# HeatingQC         5
# Alley             2
# SaleCondition     6
# GarageQual        5
# Neighborhood     25
# GarageType        6
# LandContour       4
# Electrical        5
# KitchenQual       4
# CentralAir        2
# LotConfig         5
# SaleType          9
# BsmtQual          4
# ExterCond         5
# FireplaceQu       5
# Functional        7
# GarageFinish      3
# PavedDrive        3
# HouseStyle        8
# Condition2        8
# Utilities         2
# RoofMatl          8
# MiscFeature       4
# RoofStyle         6
# GarageCond        5
# LandSlope         3
# Exterior1st      15
# Fence             4
# Exterior2nd      16
# MSZoning          5
# ExterQual         4
# LotShape          4
# Foundation        6
# Heating           6
# Condition1        9
# BldgType          5
# Street            2
# Name: unique, dtype: object

# %%
#All are categorical data having maximum categories 25

## Featurization 1
## Using dummy variables

y = df['SalePrice']
log_y = np.log1p(df['SalePrice'])

# %%
df = df.drop(['SalePrice'], axis=1)

df_total = pd.concat([df, test_df], ignore_index=True)

# %%
df_total.shape
# Out:
# (2919, 80)

# %%
df_text = df_total[non_numeric_feat]
df_num = df_total.drop(non_numeric_feat, axis=1)

# %%
df_num.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1953.500000   1965.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1993.000000     0.000000   368.500000
# 75%       6.000000  2001.000000   2004.000000   164.000000   733.000000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#           ...        GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count     ...       2918.000000  2919.000000  2919.000000    2919.000000
# mean      ...        472.874572    93.709832    47.486811      23.098321
# std       ...        215.394815   126.526589    67.575493      64.244246
# min       ...          0.000000     0.000000     0.000000       0.000000
# 25%       ...        320.000000     0.000000     0.000000       0.000000
# 50%       ...        480.000000     0.000000    26.000000       0.000000
# 75%       ...        576.000000   168.000000    70.000000       0.000000
# max       ...       1488.000000  1424.000000   742.000000    1012.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  2919.000000  2919.000000  2919.000000   2919.000000  2919.000000
# mean      2.602261    16.062350     2.251799     50.825968     6.213087
# std      25.188169    56.184365    35.663946    567.402211     2.714762
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     4.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   576.000000   800.000000  17000.000000    12.000000
#
#             YrSold
# count  2919.000000
# mean   2007.792737
# std       1.314964
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000
#
# [8 rows x 37 columns]

# %%
df_text.describe()
# Out:
#        BsmtFinType2 BsmtFinType1 MasVnrType PoolQC BsmtExposure BsmtCond  \
# count          2839         2840       2895     10         2837     2837
# unique            6            6          4      3            4        4
# top             Unf          Unf       None     Gd           No       TA
# freq           2493          851       1742      4         1904     2606
#
#        HeatingQC Alley SaleCondition GarageQual  ...    Fence Exterior2nd  \
# count       2919   198          2919       2760  ...      571        2918
# unique         5     2             6          5  ...        4          16
# top           Ex  Grvl        Normal         TA  ...    MnPrv     VinylSd
# freq        1493   120          2402       2604  ...      329        1014
#
#        MSZoning ExterQual LotShape Foundation Heating Condition1 BldgType  \
# count      2915      2919     2919       2919    2919       2919     2919
# unique        5         4        4          6       6          9        5
# top          RL        TA      Reg      PConc    GasA       Norm     1Fam
# freq       2265      1798     1859       1308    2874       2511     2425
#
#        Street
# count    2919
# unique      2
# top      Pave
# freq     2907
#
# [4 rows x 43 columns]

# %%
## Handling missing values
data_len = df_text.shape[0]
missing_drop_rate = 0.05  ## value lies between [0,1], if a column has more than this rows empty, it will be dropped
missing_threshold = data_len * missing_drop_rate

for col_name in df_text.columns:
    sum_missing = df_text[col_name].isnull().sum()
    if sum_missing > missing_threshold:
        print("Dropping",col_name)
        df_text = df_text.drop(col_name, axis=1)
# Out:
# Dropping PoolQC
# Dropping Alley
# Dropping GarageQual
# Dropping GarageType
# Dropping FireplaceQu
# Dropping GarageFinish
# Dropping MiscFeature
# Dropping GarageCond
# Dropping Fence

# %%
for col_name in df_num.columns:
    sum_missing = df_num[col_name].isnull().sum()
    if sum_missing > missing_threshold:
        print("Dropping:",col_name)
        df_num = df_num.drop(col_name, axis=1)

# %%
df_num.shape, df_text.shape
# Out:
# ((2919, 37), (2919, 34))

# %%
df_text_dummies = pd.get_dummies(df_text)
df_text_dummies.shape
# Out:
# (2919, 215)

# %%
## Now combining numeric and non_mumeric features

data_final = pd.concat([df_num, df_text_dummies], axis=1)

# %%
## separating train and test_data
train_df = data_final.iloc[:len(df)-1]
#train_df = train_df.join(log_y)

test_df = data_final.iloc[len(df)+1:]

# %%
train_df.shape, test_df.shape
# Out:
# ((1459, 253), (1458, 252))

# %%
median_tr = train_df.median()

# %%
## replacing nan values with median of training data (not test data) to avoid data leakage
 
for i,col_name in enumerate(train_df.columns):
    train_df.col_name.fillna(median_tr[i])
    test_df.col_name.fillna(median_tr[i])
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1459.000000  1459.000000  1459.000000    1459.000000  1459.000000
# mean    730.000000    56.922550   316.788897   10517.225497     6.100069
# std     421.321334    42.304033   531.750179    9984.675721     1.383171
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.500000    20.000000    60.000000    7549.000000     5.000000
# 50%     730.000000    50.000000    74.000000    9477.000000     6.000000
# 75%    1094.500000    70.000000    98.000000   11603.000000     7.000000
# max    1459.000000   190.000000  1460.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean      5.575051  1971.272104   1984.879369   111.193283   443.374914
# std       1.113125    30.212814     20.645927   206.537055   456.142186
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.000000
# 75%       6.000000  2000.000000   2004.000000   168.000000   712.000000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#           ...       Condition1_RRNe  Condition1_RRNn  BldgType_1Fam  \
# count     ...           1459.000000      1459.000000    1459.000000
# mean      ...              0.001371         0.003427       0.835504
# std       ...              0.037012         0.058460       0.370852
# min       ...              0.000000         0.000000       0.000000
# 25%       ...              0.000000         0.000000       1.000000
# 50%       ...              0.000000         0.000000       1.000000
# 75%       ...              0.000000         0.000000       1.000000
# max       ...              1.000000         1.000000       1.000000
#
#        BldgType_2fmCon  BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  \
# count      1459.000000      1459.000000     1459.000000      1459.000000
# mean          0.021247         0.035641        0.029472         0.078136
# std           0.144258         0.185457        0.169184         0.268477
# min           0.000000         0.000000        0.000000         0.000000
# 25%           0.000000         0.000000        0.000000         0.000000
# 50%           0.000000         0.000000        0.000000         0.000000
# 75%           0.000000         0.000000        0.000000         0.000000
# max           1.000000         1.000000        1.000000         1.000000
#
#        Street_Grvl  Street_Pave    SalePrice
# count  1459.000000  1459.000000  1459.000000
# mean      0.004112     0.995888    12.024141
# std       0.064018     0.064018     0.399573
# min       0.000000     0.000000    10.460271
# 25%       0.000000     1.000000    11.774913
# 50%       0.000000     1.000000    12.001512
# 75%       0.000000     1.000000    12.273736
# max       1.000000     1.000000    13.534474
#
# [8 rows x 253 columns]
